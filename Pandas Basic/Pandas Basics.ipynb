# %%
import pandas as pd

# %%
series_data = pd.Series([2,3,4,5,6,7,8])

# %%
series_data
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# 6    8
# dtype: int64

# %%
series_data.apply(lambda x:x**2)
# Out:
# 0     4
# 1     9
# 2    16
# 3    25
# 4    36
# 5    49
# 6    64
# dtype: int64

# %%
data={"Data_1":[1,2,3,4,5],"Data_2":['India','Pakistan','Bangala','Srilanka','China']}
df = pd.DataFrame(data)

# %%
df['New_data_1']=df.Data_1.apply(lambda x:x**2)

# %%
df
# Out:
#    Data_1    Data_2  New_data_1
# 0       1     India           1
# 1       2  Pakistan           4
# 2       3   Bangala           9
# 3       4  Srilanka          16
# 4       5     China          25

# %%
bank_data = pd.read_csv('/Users/prai/Downloads/Excel/bank-marketing.csv')
# Out:
# /Users/prai/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,3,6,12,16,18,19,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
bank_data = bank_data[1:]

# %%
bank_data['Order_id'] = bank_data.age.apply(lambda data:str(data)+str("_order"))
# Out:
# <ipython-input-37-4db7765a4a91>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bank_data['Order_id'] = bank_data.age.apply(lambda data:str(data)+str("_order"))

# %%
bank_data
# Out:
#       age Eligible condition  Column1 age group eligible           job  \
# 1      58                Yes      6.0         5        Y    management
# 2      44                Yes      4.0         4        Y    technician
# 3      33                 No      3.0         3        Y  entrepreneur
# 4      47                Yes      5.0         4        Y   blue-collar
# 5      33                 No      3.0         3        Y       unknown
# ...    ..                ...      ...       ...      ...           ...
# 45207  51                Yes      5.0         5        Y    technician
# 45208  71                Yes      7.0         7        N       retired
# 45209  72                Yes      7.0         7        N       retired
# 45210  57                Yes      6.0         5        Y   blue-collar
# 45211  37                 No      4.0         3        Y  entrepreneur
#
#        salary   marital  education  marital-education  ...    contact day  \
# ...

# %%
bank_data.set_index('Order_id',inplace=True)

# %%
bank_data
# Out:
#          age Eligible condition  Column1 age group eligible           job  \
# Order_id
# 58_order  58                Yes      6.0         5        Y    management
# 44_order  44                Yes      4.0         4        Y    technician
# 33_order  33                 No      3.0         3        Y  entrepreneur
# 47_order  47                Yes      5.0         4        Y   blue-collar
# 33_order  33                 No      3.0         3        Y       unknown
# ...       ..                ...      ...       ...      ...           ...
# 51_order  51                Yes      5.0         5        Y    technician
# 71_order  71                Yes      7.0         7        N       retired
# 72_order  72                Yes      7.0         7        N       retired
# 57_order  57                Yes      6.0         5        Y   blue-collar
# 37_order  37                 No      4.0         3        Y  entrepreneur
#
# ...

# %%
# Sort by index
bank_data.sort_index(ascending=True)
# Out:
#          age Eligible condition  Column1 age group eligible      job salary  \
# Order_id
# 18_order  18                 No      2.0         1        N  student   4000
# 18_order  18                 No      2.0         1        N  student   4000
# 18_order  18                 No      2.0         1        N  student   4000
# 18_order  18                 No      2.0         1        N  student   4000
# 18_order  18                 No      2.0         1        N  student   4000
# ...       ..                ...      ...       ...      ...      ...    ...
# 93_order  93                Yes      9.0         9        N  retired  55000
# 93_order  93                Yes      9.0         9        N  retired  55000
# 94_order  94                Yes      9.0         9        N  retired  55000
# 95_order  95                Yes     10.0         9        N  retired  55000
# 95_order  95                Yes     10.0         9        N  retired  55000
#
# ...

# %%
# Sort by  values by column or multiple columns
bank_data.sort_values(by=['month','job'],ascending=True,inplace=True)

# %%
bank_data
# Out:
#          age Eligible condition  Column1 age group eligible      job salary  \
# Order_id
# 26_order  26                 No      3.0         2        Y   admin.  50000
# 33_order  33                 No      3.0         3        Y   admin.  50000
# 38_order  38                 No      4.0         3        Y   admin.  50000
# 49_order  49                Yes      5.0         4        Y   admin.  50000
# 52_order  52                Yes      5.0         5        Y   admin.  50000
# ...       ..                ...      ...       ...      ...      ...    ...
# 48_order  48                Yes      5.0         4        Y  unknown      0
# 63_order  63                Yes      6.0         6        N  unknown      0
# 55_order  55                Yes      6.0         5        Y  unknown      0
# 45_order  45                Yes      5.0         4        Y  unknown      0
# 64_order  64                Yes      6.0         6        N  unknown      0
#
# ...

# %%
help(pd.DataFrame.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on some value.
#
#     ``.iloc`` will raise ``IndexError`` if a requested indexer is
#     out-of-bounds, except *slice* indexers which allow out-of-bounds
#     indexing (this conforms with python/numpy *slice* semantics).
#
# ...

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
    {'a': 100, 'b': 200, 'c': 300, 'd': 400},
    {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict)
df
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 1   100   200   300   400
# 2  1000  2000  3000  4000

# %%
df.iloc[[True, True, True]]
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 1   100   200   300   400
# 2  1000  2000  3000  4000

# %%
df.iloc[0:]
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 1   100   200   300   400
# 2  1000  2000  3000  4000

# %%
df.iloc[lambda x:x.index%2==0]
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 2  1000  2000  3000  4000

# %%
df.iloc[[0, 2], [1, 3]]
# Out:
#       b     d
# 0     2     4
# 2  2000  4000

# %%
help(pd.DataFrame.loc)
# Out:
# Help on property:
#
#     Access a group of rows and columns by label(s) or a boolean array.
#
#     ``.loc[]`` is primarily label based, but may also be used with a
#     boolean array.
#
#     Allowed inputs are:
#
#     - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#       interpreted as a *label* of the index, and **never** as an
#       integer position along the index).
#     - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#     - A slice object with labels, e.g. ``'a':'f'``.
#
#       .. warning:: Note that contrary to usual python slices, **both** the
#           start and the stop are included
#
#     - A boolean array of the same length as the axis being sliced,
#       e.g. ``[True, False, True]``.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above)
#
#     See more at :ref:`Selection by Label <indexing.label>`
#
#     Raises
#     ------
# ...
